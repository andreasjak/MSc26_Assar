# %%
import duckdb
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import re
from sklearn.preprocessing import StandardScaler
from analyte import ANALYTES
import joblib

con = duckdb.connect('../capillary.db')
df = con.execute(""" 
                 SELECT id, value,fractions, boundaries,albumin,antitrypsin,orosomukoid,haptoglobin,crp,igg,iga,igm, label, set, interpretation
                 FROM protein_data
                 WHERE value IS NOT NULL
                 AND (label = 0 OR label = 4)
                 AND analysis IS NOT NULL
                 AND protein_value IS NOT NULL
                 """).df()

con.close()

df = df[
    (df['fractions'].apply(len) == 6) &
    (df['boundaries'].apply(len) == 12)
]

protein_cols = [a.col for a in ANALYTES[:8]]  # bara de 8 första
df = df.dropna(subset=protein_cols)
y = df['label']

# Kolla klassbalansen
unique, counts = np.unique(y, return_counts=True)
for val, count in zip(unique, counts):
    print(f"Label {val}: {count} ({count/len(y)*100:.1f}%)")

df.loc[df['label'] == 4,'label'] = 1
# Out:
# Label 0: 121318 (96.8%)
# Label 4: 4049 (3.2%)

# %%
def build_X(rows):
    return np.concatenate([
        np.array(rows['value'].tolist(),     dtype=np.float32),  # (n, 300)
        np.array(rows['fractions'].tolist(), dtype=np.float32),  # (n, 6)
        np.array(rows['boundaries'].tolist(),dtype=np.float32),  # (n, 12)
        np.array(rows[protein_cols].values,  dtype=np.float32),  # (n, 8)
    ], axis=1)

train_rows = df[df['set'] == 'train']
val_rows   = df[df['set'] == 'val']
test_rows  = df[df['set'] == 'test']

drop_indices = train_rows.sample(frac=0.8).index
train_rows = train_rows.drop(drop_indices)

X_train = build_X(train_rows)
X_val   = build_X(val_rows)
X_test  = build_X(test_rows)

y_train = np.array(train_rows['label'].values, dtype=np.int64)
y_val   = np.array(val_rows['label'].values,   dtype=np.int64)
y_test  = np.array(test_rows['label'].values,  dtype=np.int64)


scaler = StandardScaler()
X_train[:, 300:] = scaler.fit_transform(X_train[:, 300:])
X_val[:, 300:]   = scaler.transform(X_val[:, 300:])
X_test[:, 300:]  = scaler.transform(X_test[:, 300:])
joblib.dump(scaler, 'scaler.pkl')

X_train, X_val, X_test = map(torch.tensor, [X_train, X_val, X_test])
y_train, y_val, y_test = map(torch.tensor, [y_train, y_val, y_test])

print(f"Total mängd träningsdata: {len(X_train)}")

for name, X, y in [('Träning', X_train, y_train), ('Validering', X_val, y_val), ('Test', X_test, y_test)]:
    print(f"{name}: {len(X):>6} ({len(X)/len(df):.0%}) | Oligoklonalt: {(y==1).sum()} | Utan: {(y==0).sum()}")

print(f"NaN: {torch.isnan(X_train).sum()}, Inf: {torch.isinf(X_train).sum()}")
# Out:
# Total mängd träningsdata: 21354
# Träning:  21354 (17%) | Oligoklonalt: 714 | Utan: 20640
# Validering:   5749 (5%) | Oligoklonalt: 208 | Utan: 5541
# Test:  12849 (10%) | Oligoklonalt: 427 | Utan: 12422
# NaN: 0, Inf: 0

# %%
batch_sz = 512

# DataLoaders
train_dataloader = DataLoader(
    TensorDataset(X_train, y_train, torch.tensor(train_rows['id'].to_numpy())),
    batch_size=batch_sz,
    shuffle=True
)

val_dataloader = DataLoader(
    TensorDataset(X_val, y_val, torch.tensor(val_rows['id'].to_numpy())),
    batch_size=batch_sz
)

test_dataloader = DataLoader(
    TensorDataset(X_test, y_test, torch.tensor(test_rows['id'].to_numpy())),
    batch_size=batch_sz
)


device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")

# Define model
class Oligoclonal(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv1d(in_channels=1,out_channels=32,kernel_size=7,padding=3),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(32,64,kernel_size=5,padding=2),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64,128,kernel_size=3,padding=1),
            nn.ReLU()
        )

        self.gap = nn.AdaptiveAvgPool1d(1)

        self.classifier = nn.Sequential(
            nn.Linear(128,64),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(64,2)
        )

    def forward(self, x):
        if x.dim() == 2:
            x = x.unsqueeze(1)
        x = self.features(x)
        x = self.gap(x)
        x = torch.flatten(x,1)
        x = self.classifier(x)
        return x
    
def train(train_dataloader, model, loss_fn, optimizer):
    model.train()
    total_loss = 0
    for batch, (X, y,_) in enumerate(train_dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        total_loss += loss.item()
    return total_loss / len(train_dataloader)


def test(test_dataloader, model, loss_fn):
    size = len(test_dataloader.dataset)
    num_batches = len(test_dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y,_ in test_dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    return (100*correct,test_loss)


model = Oligoclonal().to(device)
pos_weight = torch.tensor([1.0, 6.0], dtype=torch.float32).to(device)

loss_fn = nn.CrossEntropyLoss(weight=pos_weight)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.8)
print(model)
total_params = sum(p.numel() for p in model.parameters())
print(f"Antal parametrar: {total_params:,}")
# Out:
# Using mps device
# Oligoclonal(
#   (features): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(7,), stride=(1,), padding=(3,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv1d(32, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (4): ReLU()
#     (5): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (7): ReLU()
#   )
#   (gap): AdaptiveAvgPool1d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# Antal parametrar: 43,650

# %%
## KÖR DETTA BLOCKET FÖR ATT TRÄNA! Annars kör nästa block och läs in vikterna!
epochs = 1000
accuracies = []
validation_losses = []
train_losses = []
best_train_loss = 10000
best_val_loss = 10000
no_fails = 0

for t in range(epochs):
    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    (accuracy,val_loss) = test(val_dataloader, model, loss_fn)
    scheduler.step()
    print(f"Epoch {t:>3} | train loss: {train_loss:.4f} | val loss: {val_loss:.4f} | val acc: {accuracy:.1f}%")
    train_losses.append(train_loss)
    accuracies.append(accuracy)
    validation_losses.append(val_loss)

    if train_loss < best_train_loss:
        best_train_loss = train_loss
        no_fails = 0
        
    else:
        no_fails += 1
    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_fails =0
        torch.save(model.state_dict(), "oligoclonal_model.pth")
        print("-> ny bästa model! Saved PyTorch Model State to convolution_model.pth")
        
    if no_fails == 5:
        break
print("Done!")

torch.save(model.state_dict(), "oligoclonal_model.pth")
print("Saved PyTorch Model State to oligoclonal_model.pth")
# Out:
# Epoch   0 | train loss: 0.5718 | val loss: 0.4740 | val acc: 96.4%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch   1 | train loss: 0.4667 | val loss: 0.4545 | val acc: 96.4%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch   2 | train loss: 0.4647 | val loss: 0.4504 | val acc: 96.4%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch   3 | train loss: 0.4493 | val loss: 0.4544 | val acc: 96.4%
# Epoch   4 | train loss: 0.4462 | val loss: 0.4351 | val acc: 96.2%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch   5 | train loss: 0.4329 | val loss: 0.4315 | val acc: 96.2%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch   6 | train loss: 0.4253 | val loss: 0.4260 | val acc: 96.2%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch   7 | train loss: 0.4258 | val loss: 0.4665 | val acc: 96.4%
# Epoch   8 | train loss: 0.4279 | val loss: 0.4277 | val acc: 95.3%
# Epoch   9 | train loss: 0.4204 | val loss: 0.4241 | val acc: 96.2%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  10 | train loss: 0.4207 | val loss: 0.4345 | val acc: 96.4%
# Epoch  11 | train loss: 0.4138 | val loss: 0.4196 | val acc: 95.4%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  12 | train loss: 0.4169 | val loss: 0.4229 | val acc: 95.8%
# Epoch  13 | train loss: 0.4127 | val loss: 0.4188 | val acc: 95.1%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  14 | train loss: 0.4094 | val loss: 0.4195 | val acc: 95.9%
# Epoch  15 | train loss: 0.4064 | val loss: 0.4148 | val acc: 95.1%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  16 | train loss: 0.4121 | val loss: 0.4138 | val acc: 95.1%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  17 | train loss: 0.4038 | val loss: 0.4245 | val acc: 93.9%
# Epoch  18 | train loss: 0.4028 | val loss: 0.4109 | val acc: 94.7%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  19 | train loss: 0.4027 | val loss: 0.4164 | val acc: 94.3%
# Epoch  20 | train loss: 0.3990 | val loss: 0.4111 | val acc: 94.0%
# Epoch  21 | train loss: 0.3935 | val loss: 0.4118 | val acc: 92.5%
# Epoch  22 | train loss: 0.3985 | val loss: 0.4049 | val acc: 95.1%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  23 | train loss: 0.3858 | val loss: 0.4117 | val acc: 91.7%
# Epoch  24 | train loss: 0.3854 | val loss: 0.3941 | val acc: 95.9%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  25 | train loss: 0.3729 | val loss: 0.3841 | val acc: 94.3%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  26 | train loss: 0.3815 | val loss: 0.4055 | val acc: 96.3%
# Epoch  27 | train loss: 0.3828 | val loss: 0.3950 | val acc: 94.8%
# Epoch  28 | train loss: 0.3579 | val loss: 0.4277 | val acc: 86.6%
# Epoch  29 | train loss: 0.3528 | val loss: 0.4995 | val acc: 96.5%
# Epoch  30 | train loss: 0.3680 | val loss: 0.3710 | val acc: 93.4%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  31 | train loss: 0.3282 | val loss: 0.3241 | val acc: 94.2%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  32 | train loss: 0.3283 | val loss: 0.3172 | val acc: 94.4%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  33 | train loss: 0.3130 | val loss: 0.4770 | val acc: 96.6%
# Epoch  34 | train loss: 0.3473 | val loss: 0.3226 | val acc: 95.8%
# Epoch  35 | train loss: 0.3026 | val loss: 0.2989 | val acc: 94.7%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  36 | train loss: 0.2841 | val loss: 0.2923 | val acc: 94.0%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  37 | train loss: 0.2730 | val loss: 0.2937 | val acc: 95.9%
# Epoch  38 | train loss: 0.2723 | val loss: 0.2857 | val acc: 93.5%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  39 | train loss: 0.2648 | val loss: 0.2731 | val acc: 94.2%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  40 | train loss: 0.2616 | val loss: 0.2649 | val acc: 95.1%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  41 | train loss: 0.2540 | val loss: 0.2728 | val acc: 95.1%
# Epoch  42 | train loss: 0.2634 | val loss: 0.2777 | val acc: 92.5%
# Epoch  43 | train loss: 0.2497 | val loss: 0.3125 | val acc: 96.3%
# Epoch  44 | train loss: 0.2523 | val loss: 0.2565 | val acc: 94.3%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  45 | train loss: 0.2521 | val loss: 0.2604 | val acc: 95.2%
# Epoch  46 | train loss: 0.2441 | val loss: 0.2679 | val acc: 92.5%
# Epoch  47 | train loss: 0.2489 | val loss: 0.2791 | val acc: 96.1%
# Epoch  48 | train loss: 0.2433 | val loss: 0.2545 | val acc: 95.3%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  49 | train loss: 0.2372 | val loss: 0.2572 | val acc: 95.7%
# Epoch  50 | train loss: 0.2428 | val loss: 0.3018 | val acc: 88.7%
# Epoch  51 | train loss: 0.2380 | val loss: 0.2602 | val acc: 95.9%
# Epoch  52 | train loss: 0.2356 | val loss: 0.2499 | val acc: 93.1%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  53 | train loss: 0.2356 | val loss: 0.2480 | val acc: 94.7%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  54 | train loss: 0.2386 | val loss: 0.2512 | val acc: 95.7%
# Epoch  55 | train loss: 0.2317 | val loss: 0.2466 | val acc: 93.5%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  56 | train loss: 0.2299 | val loss: 0.2632 | val acc: 96.1%
# Epoch  57 | train loss: 0.2332 | val loss: 0.2475 | val acc: 95.3%
# Epoch  58 | train loss: 0.2317 | val loss: 0.2524 | val acc: 95.2%
# Epoch  59 | train loss: 0.2373 | val loss: 0.2489 | val acc: 95.4%
# Epoch  60 | train loss: 0.2416 | val loss: 0.2484 | val acc: 95.0%
# Epoch  61 | train loss: 0.2245 | val loss: 0.2470 | val acc: 93.4%
# Epoch  62 | train loss: 0.2304 | val loss: 0.2490 | val acc: 95.4%
# Epoch  63 | train loss: 0.2304 | val loss: 0.2530 | val acc: 95.6%
# Epoch  64 | train loss: 0.2239 | val loss: 0.2559 | val acc: 95.6%
# Epoch  65 | train loss: 0.2240 | val loss: 0.2480 | val acc: 94.4%
# Epoch  66 | train loss: 0.2393 | val loss: 0.2664 | val acc: 95.8%
# Epoch  67 | train loss: 0.2194 | val loss: 0.2426 | val acc: 93.6%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  68 | train loss: 0.2261 | val loss: 0.2376 | val acc: 93.9%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  69 | train loss: 0.2188 | val loss: 0.2393 | val acc: 94.1%
# Epoch  70 | train loss: 0.2187 | val loss: 0.2483 | val acc: 92.2%
# Epoch  71 | train loss: 0.2224 | val loss: 0.2467 | val acc: 94.7%
# Epoch  72 | train loss: 0.2190 | val loss: 0.2538 | val acc: 92.2%
# Epoch  73 | train loss: 0.2224 | val loss: 0.2377 | val acc: 93.9%
# Epoch  74 | train loss: 0.2168 | val loss: 0.2405 | val acc: 94.9%
# Epoch  75 | train loss: 0.2229 | val loss: 0.2542 | val acc: 95.3%
# Epoch  76 | train loss: 0.2144 | val loss: 0.2557 | val acc: 95.7%
# Epoch  77 | train loss: 0.2122 | val loss: 0.2471 | val acc: 95.5%
# Epoch  78 | train loss: 0.2266 | val loss: 0.2394 | val acc: 94.8%
# Epoch  79 | train loss: 0.2145 | val loss: 0.2466 | val acc: 94.4%
# Epoch  80 | train loss: 0.2208 | val loss: 0.2384 | val acc: 94.6%
# Epoch  81 | train loss: 0.2108 | val loss: 0.2496 | val acc: 95.5%
# Epoch  82 | train loss: 0.2117 | val loss: 0.2379 | val acc: 93.5%
# Epoch  83 | train loss: 0.2092 | val loss: 0.2422 | val acc: 94.8%
# Epoch  84 | train loss: 0.2116 | val loss: 0.2621 | val acc: 95.8%
# Epoch  85 | train loss: 0.2161 | val loss: 0.2439 | val acc: 95.4%
# Epoch  86 | train loss: 0.2117 | val loss: 0.2394 | val acc: 94.4%
# Epoch  87 | train loss: 0.2118 | val loss: 0.2347 | val acc: 94.4%
# -> ny bästa model! Saved PyTorch Model State to convolution_model.pth
# Epoch  88 | train loss: 0.2125 | val loss: 0.2414 | val acc: 93.4%
# Epoch  89 | train loss: 0.2081 | val loss: 0.2451 | val acc: 95.1%
# Epoch  90 | train loss: 0.2075 | val loss: 0.2428 | val acc: 94.5%
# Epoch  91 | train loss: 0.2081 | val loss: 0.2423 | val acc: 94.8%
# Epoch  92 | train loss: 0.2046 | val loss: 0.2442 | val acc: 94.4%
# Epoch  93 | train loss: 0.2065 | val loss: 0.2943 | val acc: 96.2%
# Epoch  94 | train loss: 0.2119 | val loss: 0.2451 | val acc: 95.3%
# Epoch  95 | train loss: 0.2066 | val loss: 0.2485 | val acc: 92.6%
# Epoch  96 | train loss: 0.2108 | val loss: 0.2368 | val acc: 94.4%
# Epoch  97 | train loss: 0.2055 | val loss: 0.2380 | val acc: 94.2%
# Done!
# Saved PyTorch Model State to oligoclonal_model.pth

# %%
from sklearn.metrics import classification_report, confusion_matrix

model.load_state_dict(torch.load("oligoclonal_model.pth", weights_only=True))

# Samla alla prediktioner

THRESHOLD = 0.75

model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for X, y,_ in test_dataloader:
        X, y = X.to(device), y.to(device)
        logits = model(X)
        probs = torch.softmax(logits, dim=1)[:, 1]
        pred = model(X)
        all_probs.extend(probs.cpu().numpy())
        all_labels.extend(y.cpu().numpy())

all_probs = np.array(all_probs)
all_labels = np.array(all_labels)
all_preds = (all_probs >= THRESHOLD).astype(int)

accuracy = sum(all_preds == all_labels)/len(all_preds)
missed_positives = sum( (all_labels == 1) & (all_preds == 0))/sum(all_labels ==1 )
false_positives = sum( (all_labels == 0) & (all_preds == 1))/sum(all_labels == 1)

# Hitta FN
fn_idx = np.where((all_labels == 1) & (all_preds == 0))[0]
print(f"Antal FN: {len(fn_idx)}")
# Rapport
print(classification_report(all_labels, all_preds, target_names=['Negativ', 'Positiv']))
print(confusion_matrix(all_labels, all_preds))
print(f"Overall accuracy (using threshold): {100*accuracy:.2f}%")
print(f"False negative rate, i.e dangerous percentage (using threshold): {100*missed_positives:.2f}%")
print(f"False positive rate, i.e unneccesary alarm (using threshold): {100*false_positives:.2f}%")
# Out:
# Antal FN: 253
#               precision    recall  f1-score   support
#
#      Negativ       0.98      0.98      0.98     12422
#      Positiv       0.42      0.41      0.41       427
#
#     accuracy                           0.96     12849
#    macro avg       0.70      0.69      0.70     12849
# weighted avg       0.96      0.96      0.96     12849
#
# [[12179   243]
#  [  253   174]]
# Overall accuracy (using threshold): 96.14%
# False negative rate, i.e dangerous percentage (using threshold): 59.25%
# False positive rate, i.e unneccesary alarm (using threshold): 56.91%

# %%
# Analys av hur träningen gick
import matplotlib.pyplot as plt

plt.plot(validation_losses, label='validation loss')
plt.plot(train_losses, label = 'train loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training loss')
plt.grid(True)
plt.show()

# %%
import textwrap



THRESHOLD = 0.75
model.eval()

all_probs = []
all_labels = []
all_ids = []

with torch.no_grad():
    for X, y, ids in val_dataloader:
        X, y = X.to(device), y.to(device)
        logits = model(X)
        probs = torch.softmax(logits, dim=1)[:, 1]

        all_probs.extend(probs.cpu().numpy())
        all_labels.extend(y.cpu().numpy())
        all_ids.extend(ids.cpu().numpy())

all_probs  = np.array(all_probs)
all_labels = np.array(all_labels)
all_ids    = np.array(all_ids)

all_preds  = (all_probs >= THRESHOLD).astype(int)

fn_idx = np.where((all_labels == 1) & (all_preds == 0))[0]
print(f"Antal FN: {len(fn_idx)}")

# Plotta
fn_sample = np.random.choice(fn_idx, size=min(3, len(fn_idx)), replace=False)
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
id_to_row = val_rows.set_index('id')

for ax, idx in zip(axes.flat, fn_sample):
    row_id = all_ids[idx]

    row = id_to_row.loc[row_id]

    curve = row['value'][0:300]
    interpretation = row['interpretation']

    ax.plot(curve)
    ax.set_title(f"id={row_id} | p={all_probs[idx]:.2f}")
    ax.set_xlabel("Position")
    ax.set_ylabel("Value")
    ax.set_ybound(lower=0,upper=4000)

    wrapped = "\n".join(textwrap.wrap(interpretation, width=40))
    ax.text(
    0.5, -0.3,
    wrapped,
    transform=ax.transAxes,
    ha='center',
    va='top',
    fontsize=8
    )

plt.figure()
plt.suptitle("Falska negativa — kurvor")
plt.show()
# Out:
# Antal FN: 123
